# %%
#Author: Christine Nguyen

import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
sales = pd.read_pickle('sales.pkl')

# %%
sales.head()
# Out:
#    LotSizeAcres                                     PrivateRemarks  \
# 0           NaN  Trust Sale.  Property is sold in "as is" condi...
# 1           NaN  NOTE: This property is located in the Portugue...
# 2           NaN  Offer accepted.  Buyer to verify square footag...
# 3          0.49  Sq Ft, lot size as well as bed and bath count ...
# 4           NaN  ** ACCEPTING BACK UP OFFERS **.  Please submit...
#
#                                         Appliances  AppliancesYN MLSAreaMajor  \
# 0                                        Microwave           1.0          NaN
# 1    Dishwasher, Disposal, Microwave, Refrigerator           1.0          NaN
# 2  Dishwasher, Disposal, Microwave, Built-In Range           1.0          NaN
# 3                                 Gas Water Heater           1.0          NaN
# 4                             Dishwasher, Disposal           1.0          NaN
#
#   Assessments  AssessmentsYN  ParcelNumber  AssociationFee  AssociationYN  \
# ...

# %%
test = sales[columnsList]

# %%
test.head()
# Out:
#    AttachedGarageYN  BathroomsTotalInteger  BedroomsTotal  \
# 0               NaN                      2              3
# 1               0.0                      2              3
# 2               NaN                      2              4
# 3               1.0                      3              4
# 4               NaN                      3              3
#
#                   City  CloseDate  ClosePrice  CoolingYN Country  \
# 0  Rancho Palos Verdes    43951.0   1225000.0        1.0     NaN
# 1  Rancho Palos Verdes    43860.0   1285000.0        0.0     NaN
# 2  Rancho Palos Verdes    43840.0   1300000.0        0.0      US
# 3  Rancho Palos Verdes    43781.0   1432500.0        NaN     NaN
# 4  Rancho Palos Verdes    44047.0   1455000.0        0.0      US
#
#   CountyOrParish CountyOrParish  FireplaceYN  HeatingYN HighSchoolDistrict  \
# 0    Los Angeles    Los Angeles          1.0        1.0                NaN
# ...

# %%
test.AttachedGarageYN.unique()
# Out:
# array([nan,  0.,  1.])

# %%
#calculating percent of missing data 
percent_missing = test.isnull().sum() * 100 / len(test)
missing_value_df = pd.DataFrame({'column_name': test.columns,
                                 'percent_missing': percent_missing})
missing_value_df.reset_index(drop = True, inplace = True)
# missing_value_df.sort_values()

# %%
missing_value_df.sort_values('percent_missing', inplace = True)

# %%
missing_value_df
# Out:
#                        column_name  percent_missing
# 16                       ListPrice         0.000000
# 38             StreetNumberNumeric         0.000000
# 29                    PropertyType         0.000000
# 28                 PropertySubType         0.000000
# 25                     PhotosCount         0.000000
# 36                      StreetName         0.000000
# 13  InternetEntireListingDisplayYN         0.000000
# 9                   CountyOrParish         0.000000
# 33                 StateOrProvince         0.000000
# 1            BathroomsTotalInteger         0.000000
# 2                    BedroomsTotal         0.000000
# 3                             City         0.000000
# 8                   CountyOrParish         0.000000
# 14                        Latitude         0.018349
# 5                       ClosePrice         0.018349
# 18                       Longitude         0.018349
# 17                      LivingArea         0.055046
# ...

# %%
import missingno as msno
msno.matrix(sales)

# %%
sales.columns
# Out:
# Index(['LotSizeAcres', 'PrivateRemarks', 'Appliances', 'AppliancesYN',
#        'MLSAreaMajor', 'Assessments', 'AssessmentsYN', 'ParcelNumber',
#        'AssociationFee', 'AssociationYN',
#        ...
#        'PostalCodePlus4', 'SpaYN', 'VirtualTourURLUnbranded', 'SprinklersYN',
#        'CountyOrParish', 'StreetNumber', 'StreetSuffixModifier',
#        'StreetDirSuffix', 'Zoning', 'StreetDirPrefix'],
#       dtype='object', length=178)

# %%
# for i in sales.columns:
#     print(i)

# %%
numerical = [
'BathroomsTotalInteger',
'BedroomsTotal',
'ClosePrice',
'Latitude',
'ListPrice',
'Longitude',
'LotSizeSquareFeet',
'ParcelNumber',
'ParkingTotal',
'PhotosCount',
'PostalCode'
]

# %%
categorical = [
'AttachedGarageYN',
'BathroomsTotalInteger',
'BedroomsTotal',
'CloseDate',
'ClosePrice',
'CoolingYN',
'FireplaceYN',
'HeatingYN',
'HighSchoolDistrict',
'InternetEntireListingDisplayYN',
'LaundryYN',
'LivingArea',
'MLSAreaMajor',
'ParcelNumber',
'ParkingYN',
'PatioYN',
'PoolPrivateYN',
'PostalCode',
'PropertySubType',
'PropertyType',
'SignOnPropertyYN',
'SpaYN',
'SprinklersYN',
'ViewYN',
'VirtualTourURLUnbranded',
'YearBuilt',
'Zoning'
]

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

#using pearson's correlation for continuous variabes 
corr = test[numerical].corr()
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values)

#please note this, you need to seperate out the continuous and categorical variables before you do the correlation analysis
#there are different kinds of correlation analysis techniques used for both kinds of variables... below is just for an example sake.
